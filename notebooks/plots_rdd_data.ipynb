# %% [markdown]
# ## Plots of R&D data
# This notebook contains examples of the plotting utilities for visualizing the data set on R&D spending on renewable energy technologies

# %%
import os
import sys
import numpy as np
import json
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %config InlineBackend.figure_formats = ['svg']
# %matplotlib inline

# hack to be able to load modules from parent directory
sys.path.insert(0, os.path.dirname(os.getcwd()))
from src.utils.plotting import plot_rdd

# %%
# load data on RD&D spending
rdd_data = pd.read_csv('../data/rdd_data_selected.csv')

# %%
rdd_data
# Out:
#            country    product  year  budget_renewables  budget_total  \
# 0          Austria  RDDUSDPPP  1990              3.671        22.212
# 1          Austria  RDDUSDPPP  1991              8.418        38.161
# 2          Austria  RDDUSDPPP  1992              7.245        31.711
# 3          Austria  RDDUSDPPP  1993              9.878        42.004
# 4          Austria  RDDUSDPPP  1994             12.774        46.335
# ..             ...        ...   ...                ...           ...
# 475  United States  RDDUSDPPP  2015            977.549      6576.180
# 476  United States  RDDUSDPPP  2016            774.232      6710.956
# 477  United States  RDDUSDPPP  2017            710.385      6733.524
# 478  United States  RDDUSDPPP  2018            777.975      7616.869
# 479  United States  RDDUSDPPP  2019            776.799      8159.546
#
#      share_budget_renewables
# 0                  16.527102
# 1                  22.059170
# 2                  22.846962
# ...

# %%
# plot data for all countries, no averaging
plot_rdd(rdd_data)

# %%
# plot data for all countries, running avg. with 3-year-window
plot_rdd(rdd_data, avg_window=5)

# %%
# plot data for selected countries, running avg. with 3-year-windos
plot_rdd(rdd_data, avg_window=3, selected=['Austria', 'Sweden'], plot_non_avg=True)
